# %%
# ───────────────────────────────────────────────────────────────────────────────
# CBD_MDE_2025 — Data Cleaning & Preprocessing Pipeline
#
# Research question:
#   What are the specific logistics needs within CBDs, and how can alignment
#   of supply and demand inform UCC implementation in LEZs?
#
# This script cleans and preprocesses the survey data for downstream FAMD,
# clustering, correspondence analysis, and visualization.
# ───────────────────────────────────────────────────────────────────────────────

# 1. Initial Setup
#    1.1 Import libraries
import pandas as pd
import numpy as np
import unicodedata
import re
from pathlib import Path
from pandas.api.types import CategoricalDtype
from sklearn.preprocessing import MultiLabelBinarizer
# (prince, KMeans, silhouette_score, matplotlib will be used later)

#    1.2 Locate project root & raw data
project_root = Path.cwd().resolve().parents[1]
data_file    = project_root / "data" / "raw" / "03. Resultados_encuesta_logistica_ZUAP_20220927_v1.xlsx"
print("Project root:", project_root)
print("Data file:", data_file)

# load the actual responses
df_raw = pd.read_excel(data_file, sheet_name="Respuestas")
print("Raw shape:", df_raw.shape)
print(df_raw.columns.tolist())
print(df_raw.head())

# 2. Load & Rename Raw Survey
#    2.1 Read Excel, strip whitespace, lowercase headers, parse timestamps
def dataframe_cleaning(path):
    df = pd.read_excel(path)
    df.columns = df.columns.str.strip().str.lower()
    df = df.apply(lambda col: col.map(lambda x: x.strip() if isinstance(x, str) else x))

    if 'marca temporal' in df.columns:
        df['marca temporal'] = pd.to_datetime(df['marca temporal'], errors='coerce')
    df = df.drop_duplicates()

    #    2.2 Drop non‐informative Spanish‐named columns
    drop_cols = [
        # Database flag
        'db',
        # “Go to end of survey.”
        'ir al fin de la encuesta.',
        
        # “By type of load, select up to 3”
        'de acuerdo con el tipo de carga que distribuye su empresa, indique máximo 3 tipos en el siguiente listado:',
        # Origin in Valle de Aburrá?
        '¿el origen de la mercancía que transporta es el valle de aburrá?',
        # Municipality of origin
        'por favor, indique el municipio:',
        # Daily deliveries to downtown Medellín
        'por favor, indique cuántas entregas hace en el centro de medellín al día:',
        # Daily number of establishments served downtown
        'por favor, indique el número de establecimientos que surte en el centro de medellín a diario:',
        # Daily orders received for downtown
        '¿cuántos pedidos recibe su empresa diariamente que tienen como destino el centro de medellín?',
        # Fleet composition by fuel type
        'por favor indique la cantidad de vehículos con combustión a diésel (acpm) con los que cuenta su empresa:',
        'por favor indique la cantidad de vehículos con combustión a gasolina con los que cuenta su empresa:',
        'por favor indique la cantidad de vehículos con combustión a gas natural vehicular (gnv) con los que cuenta su empresa:',
        'por favor indique la cantidad de vehículos con motor eléctrico con los que cuenta su empresa:',
        # Vehicle age ranges
        'por favor, indique el rango de edad promedio del parque vehicular de su empresa [modelos anteriores a 1990]',
        'por favor, indique el rango de edad promedio del parque vehicular de su empresa [modelos entre 1991 y 2000]',
        'por favor, indique el rango de edad promedio del parque vehicular de su empresa [modelos entre 2001 y 2010]',
        'por favor, indique el rango de edad promedio del parque vehicular de su empresa [modelos entre 2011 y 2015]',
        'por favor, indique el rango de edad promedio del parque vehicular de su empresa [modelos del 2016 en adelante]',
        # Fuel/energy economy metrics
        '¿cuánto es el rendimiento en galones/kilómetro, de sus vehículos a acpm?',
        '¿cuánto es el rendimiento en galones/kilómetro, de sus vehículos a gasolina?',
        '¿cuánto es el rendimiento en metros cúbicos/kilómetro, de sus vehículos a gnv?',
        '¿cuánto es el rendimiento kilowatt-hora, de sus vehículos eléctricos?',
        # Cost and driver-hours metrics
        '¿cuánto es el costo total por movilizar un camión cargado hacia el centro de medellín?',
        '¿cuántas horas al volante permanece durante un turno de reparto una/un conductora/or en su empresa?',
        # Driver‐road‐user relationship (1=very complex…5=very adequate)
        'de acuerdo con la siguiente escala, donde 1 es "muy compleja" y 5 es "muy adecuada" ¿cómo considera la relación de sus conductores con los demás actores viales (peatones, ciclistas, conductores, transporte público) en el espacio público de la zuap?',
        # In‐company physical‐activity programs
        '¿al interior de su empresa se realizan actividades que promuevan la actividad física entre sus calaboradoras/es?',
        '¿qué actividades se realizan?',
        '¿cuántas veces por semana se realizan actividades para promover la actividad física?',
        # Awareness of Yellow Zone decree
        '¿conoce usted el decreto no 1790 de noviembre 20 de 2012 (decreto de zona amarilla o de cargue y descargue en el centro de la ciudad)?'
    ]
    df = df.drop(columns=drop_cols, errors='ignore')

    #    2.3 Rename remaining to concise English
    rename_map = {
        'marca temporal': 'timestamp',
        'nombre de la empresa': 'company_name',
        'correo electrónico': 'email',
        'dirección de la empresa': 'est_address',
        'teléfono de contacto': 'contact_phone',
        'por favor indique el número de colaboradores que tiene su empresa o comercio': 'employees',
        '¿en su empresa o comercio cuentan con colaboradoras mujeres?': 'has_female_employees',
        'por favor indique el número de mujeres que trabajan en su empresa o comercio': 'female_employees',
        'porcentaje mujeres': 'female_percentage',
        'de sus empleadas mujeres, ¿cuántas hacen parte de la cadena de distribución del negocio (conducen, reparten domicilios, acompañan las entregas, etc.)?': 'female_in_distribution',
        '% mujeres en la distribución': 'pct_female_in_distribution',
        'de las mujeres vinculadas a la cadena logística de su empresa o comercio ¿cuántas están vinculadas por contrato laboral?': 'female_with_contract',
        '% mujeres vinculadas': 'pct_female_with_contract',
        'entre sus colaboradoras mujeres, alguna(s) se identifica(n) con los siguientes grupos poblacionales:': 'female_population_groups',
        '¿acompañan y/o apoyan el proceso formativo de las mujeres que hacen parte de la cadena logística?': 'female_support_roles',
        'por favor, indique dentro de la siguientes categorías, cuál se relaciona con la actividad realizada en su comercio:': 'economic_activity',
        'de acuerdo al listado señale en orden de importancia las 3 principales actividades comerciales que se desarrollan en su establecimiento:': 'top_3_activities',
        'productos principales': 'main_products',
        '¿su establecimiento cuenta con espacio de bodega o almacenamiento de mercancías o productos?': 'has_warehouse_space',
        '¿con cuántos espacios de bodega cuenta?': 'warehouse_count',
        '¿en qué piso se ubica(n) la(s) bodegas que sirven a su empresa o comercio?': 'warehouse_floor',
        'por favor, indique el área de la bodega que sirve a su comercio en metros cuadrados:': 'warehouse_area_m2',
        'por favor, indique la altura en metros de la bodega que sirve a su comercio:': 'warehouse_height_m',
        '¿el(los) espacio(s) de bodega están ubicados al interior de la zuap?': 'warehouse_within_zuap',
        '¿en qué municipio se encuentra ubicada la bodega que sirve a su comercio?': 'warehouse_municipality',
        'por favor, indique el tipo de bodega con la que cuenta:': 'warehouse_type',
        'por favor, seleccione los días en los cuales recibe materiales, materias primas o productos:': 'supply_day',
        '¿cuántas veces por semana abastece su establecimiento?': 'supply_frequency_per_week',
        'por favor, indique los horarios durante los cuales realiza las actividades de cargue y descargue de las mercancías:': 'loading_schedule',
        'por favor, indique la forma en la que ingresa la mercancía a su comercio o área de bodega:': 'unloading_method',
        'en una escala de 1 a 5, donde 1 es "muy inseguro" y 5 "muy seguro", ¿considera usted que el proceso de cargue y descargue de mercancías en camión, carro o motocicleta es?': 'safety_perception_motorized',
        'en una escala de 1 a 5, donde 1 es "muy inseguro" y 5 "muy seguro", ¿considera usted que el proceso de cargue y descargue de mercancías en bicicleta es?': 'safety_perception_bicycle',
        '¿el establecimiento o bodega posee alguno de los siguientes elementos para el cargue y descargue de mercancías?': 'loading_equipment',
        '¿qué medio realiza para el envío de sus artículos a domicilio?': 'delivery_modes',
        '¿cuántos domicilios realiza a diario su establecimiento?': 'daily_delivery_count',
        '¿qué medio realiza para el envío de sus ventas por internet?': 'online_delivery_modes',
        '¿cuántos envíos de artículos vendidos por internet realiza a diario su establecimiento?': 'daily_online_delivery_count'
    }
    return df.rename(columns=rename_map)

df_clean = dataframe_cleaning(data_file)
print("df_clean shape:", df_clean.shape)
print(df_clean.columns.tolist())
print(df_clean.head())
print("original info:", df_clean.info())

#check repeated results in columns
print("Checking unique values in each column:")
for col in df_clean.columns[6:]:
    if col in df_clean.columns:
        uniques = df_clean[col].unique()
        print(f"{col} ({len(uniques)} unique):")
        print(uniques)
        print("-" * 40)
    else:
        print(f"{col}: [Column not found in df_clean]")
        print("-" * 40)

# 3. Initial Type Adjustment
#    3.1 Single‐label categorical → category
categorical__nominal_cols = [
    "main_products", "has_warehouse_space", "warehouse_within_zuap",
    "warehouse_municipality", "warehouse_type", "economic_activity","female_support_roles"
]
for col in categorical__nominal_cols:
    df_clean[col] = df_clean[col].astype("category")

#    3.2 Multi‐label text fields → string (to explode later)
multi_col_text = ["top_3_activities","supply_day","loading_schedule",
              "unloading_method","loading_equipment",
              "delivery_modes","online_delivery_modes","female_population_groups"]
for col in multi_col_text:
    df_clean[col] = df_clean[col].astype(str)

#    3.3 Ordinal factors
#        3.3.1 Floors as ordered categories
floor_cats = sorted(df_clean["warehouse_floor"].dropna().unique(), key=float)
df_clean["warehouse_floor"] = df_clean["warehouse_floor"]\
    .astype(CategoricalDtype(categories=floor_cats, ordered=True))
#        3.3.2 Likert scales 1–5
likert = CategoricalDtype(categories=[1,2,3,4,5], ordered=True)
for col in ["safety_perception_motorized","safety_perception_bicycle"]:
    df_clean[col] = df_clean[col].astype(likert)

#    3.4 Numeric counts & measures
num_cols = ["warehouse_count","warehouse_area_m2","warehouse_height_m",
            "daily_delivery_count","daily_online_delivery_count",
            "employees","female_employees",
            "female_in_distribution","female_with_contract"]
for col in num_cols:
    df_clean[col] = pd.to_numeric(df_clean[col], errors="coerce")

#    3.5 Percentages → float
for col in ["female_percentage","pct_female_in_distribution","pct_female_with_contract"]:
    df_clean[col] = df_clean[col].astype(float)

#    3.6 Supply frequency → extract numeric & ordered
freq_map = {
    "1 vez por semana":1, "2":2, "5":5, "6 o más":6,
    "La periodicidad es quincenal":2, "La periodicidad es mensual":1
}
df_clean["supply_frequency_num"] = (
    df_clean["supply_frequency_per_week"]
      .map(freq_map).fillna(0).astype(int)
      .astype(CategoricalDtype(categories=[1,2,5,6], ordered=True))
)

#    3.7 Remaining text as category
descriptive_cols = ["email", "company_name", "est_address", "contact_phone"]

for col in descriptive_cols:
    df_clean[col] = df_clean[col].astype("category")

print("df_clean shape:", df_clean.shape)
print(df_clean.columns.tolist())
print(df_clean.head())
print("New df info:", df_clean.info())


# Check new unique values in each column from the 6th column onward
print("\nUnique values in each column (from index 6):")
for col in df_clean.columns[6:]:
    uniques = df_clean[col].dropna().unique()
    print(f"{col} ({len(uniques)} unique):")
    print(uniques)
    print("-" * 40)


# 4. Normalize & Translate Text
#    4.1 Helper: lowercase, strip accents
def normalize_text(s: str) -> str:
    if pd.isna(s):
        return ""
    s = str(s)
    s = unicodedata.normalize("NFKD", s)
    s = "".join(c for c in s if not unicodedata.combining(c))  # strip accents
    s = s.lower().strip()
    s = re.sub(r"\s+", " ", s)
    return s

#    4.2 warehouse_within_zuap
YESNO = {"sí":"yes","si":"yes","no":"no","no aplica":pd.NA}

# Normalize and map warehouse_within_zuap values
df_clean["warehouse_within_zuap"] = (
    df_clean["warehouse_within_zuap"]
      .map(normalize_text)
      .replace(YESNO)
      .astype("category")
)
# Show unique values for verification
print("warehouse_within_zuap (unique):", df_clean["warehouse_within_zuap"].unique())

# 4.3 Clean main_products without collapsing to top-N: preserve each row’s unique value
df_clean["main_products"] = (
    df_clean["main_products"]
      .map(normalize_text)          # normalize case, remove accents, trim
      .astype("category")           # cast to categorical, retaining all unique levels
)

print("Normalized main_products (unique):", df_clean["main_products"].unique())

# 4.4 Main categories exactly as they appear in original data
main_cats = ["Venta al detalle", "Fabricante", "Proveedor", "Ventas por internet"]

def split_econ_preserve_caps(x):
    if pd.isna(x):
        return pd.Series([pd.NA, pd.NA, pd.NA])
    
    # Step 1: Find matching main category (case-sensitive match)
    main = next((m for m in main_cats if x.startswith(m)), None)
    if main is None:
        return pd.Series([x, pd.NA, pd.NA])  # fallback
    
    # Step 2: Strip out main part and work with the rest
    rest = x[len(main):].strip()
    if not rest:
        return pd.Series([main, pd.NA, pd.NA])
    
    # Step 3: Use regex to find segments that start with uppercase (incl. accents)
    parts = re.findall(r'([A-ZÁÉÍÓÚÑ][^A-ZÁÉÍÓÚÑ]*)', rest)
    sub1 = parts[0].strip() if len(parts) >= 1 else pd.NA
    sub2 = parts[1].strip() if len(parts) >= 2 else pd.NA
    
    return pd.Series([main, sub1, sub2])

# Apply the split (no normalization!)

# ensure economic_activity is treated as plain strings for the split
econ_split = df_clean["economic_activity"].astype(str).apply(split_econ_preserve_caps)

df_clean[["econ_main", "econ_sub1", "econ_sub2"]] = econ_split

for col in ["econ_main", "econ_sub1", "econ_sub2"]:
    df_clean[col] = df_clean[col].astype("category")

# Verify outcome
print("Last df_clean",df_clean[["economic_activity", "econ_main", "econ_sub1", "econ_sub2"]].head())

# add step to 
    #Translate the df_clean DataFrame
# Out:
# Project root: C:\Users\cgranadamunoz\OneDrive - Universidad Nacional de Colombia\UCC - General\CBD_MDE_2025
# Data file: C:\Users\cgranadamunoz\OneDrive - Universidad Nacional de Colombia\UCC - General\CBD_MDE_2025\data\raw\03. Resultados_encuesta_logistica_ZUAP_20220927_v1.xlsx
# Raw shape: (487, 66)
# ['id', 'db', 'Marca temporal', 'Correo electrónico', 'Nombre de la empresa', 'Dirección de la empresa', 'Teléfono de contacto', 'Por favor indique el número de colaboradores que tiene su empresa o comercio', '¿En su empresa o comercio cuentan con colaboradoras mujeres?', 'Por favor indique el número de mujeres que trabajan en su empresa o comercio', 'Porcentaje mujeres', 'De sus empleadas mujeres, ¿Cuántas hacen parte de la cadena de distribución del negocio (conducen, reparten domicilios, acompañan las entregas, etc.)?', '% mujeres en la distribución', 'De las mujeres vinculadas a la cadena logística de su empresa o comercio ¿Cuántas están vinculadas por contrato laboral?', '% mujeres vinculadas', 'Entre sus colaboradoras mujeres, alguna(s) se identifica(n) con los siguientes grupos poblacionales:', '¿Acompañan y/o apoyan el proceso formativo de las mujeres que hacen parte de la cadena logística?', 'Por favor, indique dentro de la siguientes categorías, cuál se relaciona con la actividad realizada en su comercio:', 'De acuerdo al listado señale en orden de importancia las 3 principales actividades comerciales que se desarrollan en su establecimiento:', 'Productos principales', '¿Su establecimiento cuenta con espacio de bodega o almacenamiento de mercancías o productos?', '¿Con cuántos espacios de bodega cuenta?', '¿En qué piso se ubica(n) la(s) bodegas que sirven a su empresa o comercio?', 'Por favor, indique el área de la bodega que sirve a su comercio en metros cuadrados:', 'Por favor, indique la altura en metros de la bodega que sirve a su comercio:', '¿El(los) espacio(s) de bodega están ubicados al interior de la ZUAP?', '¿En qué municipio se encuentra ubicada la bodega que sirve a su comercio?', 'Por favor, indique el tipo de bodega con la que cuenta:', 'Por favor, seleccione los días en los cuales recibe materiales, materias primas o productos:', '¿Cuántas veces por semana abastece su establecimiento?', 'Por favor, indique los horarios durante los cuales realiza las actividades de cargue y descargue de las mercancías:', 'Por favor, indique la forma en la que ingresa la mercancía a su comercio o área de bodega:', 'En una escala de 1 a 5, donde 1 es "Muy inseguro" y 5 "Muy seguro", ¿considera usted que el proceso de cargue y descargue de mercancías en camión, carro o motocicleta es?', 'En una escala de 1 a 5, donde 1 es "Muy inseguro" y 5 "Muy seguro", ¿considera usted que el proceso de cargue y descargue de mercancías en bicicleta es?', '¿El establecimiento o bodega posee alguno de los siguientes elementos para el cargue y descargue de mercancías?', '¿Qué medio realiza para el envío de sus artículos a domicilio?', '¿Cuántos domicilios realiza a diario su establecimiento?', '¿Qué medio realiza para el envío de sus ventas por internet?', '¿Cuántos envíos de artículos vendidos por internet realiza a diario su establecimiento?', 'Ir al fin de la encuesta.', 'De acuerdo con el tipo de carga que distribuye su empresa, indique máximo 3 tipos en el siguiente listado:', '¿El origen de la mercancía que transporta es el Valle de Aburrá?', 'Por favor, indique el municipio:', 'Por favor, indique cuántas entregas hace en el centro de Medellín al día:', 'Por favor, indique el número de establecimientos que surte en el centro de Medellín a diario:', '¿Cuántos pedidos recibe su empresa diariamente que tienen como destino el centro de Medellín?', 'Por favor indique la cantidad de vehículos con combustión a diésel (ACPM) con los que cuenta su empresa:', 'Por favor indique la cantidad de vehículos con combustión a gasolina con los que cuenta su empresa:', 'Por favor indique la cantidad de vehículos con combustión a gas natural vehicular (GNV) con los que cuenta su empresa:', 'Por favor indique la cantidad de vehículos con motor eléctrico con los que cuenta su empresa:', 'Por favor, indique el rango de edad promedio del parque vehicular de su empresa [Modelos anteriores a 1990]', 'Por favor, indique el rango de edad promedio del parque vehic ...
#    id  db          Marca temporal                        Correo electrónico  \
# 0   1  dt 2022-05-17 11:20:36.160      Gestiohumana@111tiendasdebelleza.com
# 1   2  dt 2022-05-18 11:17:48.282   CalzadobucaramangaMedellín2@hotmail.com
# 2   3  dt 2022-05-18 08:28:01.487                                 No aplica
# 3   4  dt 2022-05-16 16:22:43.406  comercializadoracentermedmatur@gmail.com
# 4   5  dt 2022-05-16 15:54:14.360                      pipemotos@gmail.com
#
#                    Nombre de la empresa    Dirección de la empresa  \
# 0     Iversiones111t tiendas de belleza  CL 48 54 43 local 102 108
# 1  Distri zapatos - calzado bucaramanga                 Cr 54 4803
# 2                       Molina y arango            Calle 44a 54 32
# 3              Comercializadora center              Calle 46 53 05
# 4                           Pipe motos           Calle  45 53 A 12
#
#   Teléfono de contacto  \
# 0              5110950
# 1           3147907153
# 2           3103978026
# 3              5134081
# 4  5898256 -3295338608
#
#    Por favor indique el número de colaboradores que tiene su empresa o comercio  \
# 0                                                 13
# 1                                                 12
# 2                                                  3
# 3                                                 32
# 4                                                  3
#
#   ¿En su empresa o comercio cuentan con colaboradoras mujeres?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 No
# 3                                                 Sí
# 4                                                 No
#
#    Por favor indique el número de mujeres que trabajan en su empresa o comercio  \
# 0                                                5.0
# 1                                                9.0
# 2                                                NaN
# 3                                               20.0
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    ¿Cuánto es el rendimiento en galones/kilómetro, de sus vehículos a gasolina?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ¿Cuánto es el rendimiento en metros cúbicos/kilómetro, de sus vehículos a GNV?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ¿Cuánto es el rendimiento kilowatt-hora, de sus vehículos eléctricos?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ¿Cuánto es el costo total por movilizar un camión cargado hacia el centro de Medellín?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ¿Cuántas horas al volante permanece durante un turno de reparto una/un conductora/or en su empresa?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   De acuerdo con la siguiente escala, donde 1 es "Muy compleja" y 5 es "Muy adecuada" ¿Cómo considera la relación de sus conductores con los demás actores viales (peatones, ciclistas, conductores, transporte público) en el espacio público de la ZUAP?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Al interior de su empresa se realizan actividades que promuevan la actividad física entre sus calaboradoras/es?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué actividades se realizan?  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   ¿Cuántas veces por semana se realizan actividades para promover la actividad física?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Conoce usted el Decreto No 1790 de noviembre 20 de 2012 (Decreto de Zona Amarilla o de cargue y descargue en el centro de la ciudad)?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 66 columns]
# df_clean shape: (487, 38)
# ['id', 'timestamp', 'email', 'company_name', 'est_address', 'contact_phone', 'employees', 'has_female_employees', 'female_employees', 'female_percentage', 'female_in_distribution', 'pct_female_in_distribution', 'female_with_contract', 'pct_female_with_contract', 'female_population_groups', 'female_support_roles', 'economic_activity', 'top_3_activities', 'main_products', 'has_warehouse_space', 'warehouse_count', 'warehouse_floor', 'warehouse_area_m2', 'warehouse_height_m', 'warehouse_within_zuap', 'warehouse_municipality', 'warehouse_type', 'supply_day', 'supply_frequency_per_week', 'loading_schedule', 'unloading_method', 'safety_perception_motorized', 'safety_perception_bicycle', 'loading_equipment', 'delivery_modes', 'daily_delivery_count', 'online_delivery_modes', 'daily_online_delivery_count']
#    id               timestamp                                     email  \
# 0   1 2022-05-17 11:20:36.160      Gestiohumana@111tiendasdebelleza.com
# 1   2 2022-05-18 11:17:48.282   CalzadobucaramangaMedellín2@hotmail.com
# 2   3 2022-05-18 08:28:01.487                                 No aplica
# 3   4 2022-05-16 16:22:43.406  comercializadoracentermedmatur@gmail.com
# 4   5 2022-05-16 15:54:14.360                       pipemotos@gmail.com
#
#                            company_name                est_address  \
# 0     Iversiones111t tiendas de belleza  CL 48 54 43 local 102 108
# 1  Distri zapatos - calzado bucaramanga                 Cr 54 4803
# 2                       Molina y arango            Calle 44a 54 32
# 3               Comercializadora center             Calle 46 53 05
# 4                            Pipe motos          Calle  45 53 A 12
#
#          contact_phone  employees has_female_employees  female_employees  \
# 0              5110950         13                   Sí               5.0
# 1           3147907153         12                   Sí               9.0
# 2           3103978026          3                   No               NaN
# 3              5134081         32                   Sí              20.0
# 4  5898256 -3295338608          3                   No               NaN
#
#    female_percentage  ...  supply_frequency_per_week  \
# 0           0.384615  ...                          5
# 1           0.750000  ...                    6 o más
# 2           0.000000  ...                    6 o más
# 3           0.625000  ...                          5
# 4           0.000000  ...           1 vez por semana
#
#                                     loading_schedule  \
# 0  08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 1...
# 1  08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 1...
# 2  09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 1...
# 3        10:00 a 11:00, 14:00 a 15:00, 16:00 a 17:00
# 4                                      09:00 a 10:00
#
#                                     unloading_method  \
# 0  En camión, estacionado en zona bahía y la ingr...
# 1                              En carreta "zorrilla"
# 2     En camión, sobre la vía, En carreta "zorrilla"
# 3  En camión, estacionado en zona bahía y la ingr...
# 4            En camión, sobre la vía, En motocicleta
#
#    safety_perception_motorized safety_perception_bicycle  \
# 0                            2                         1
# 1                            3                         3
# 2                            5                         1
# 3                            5                         1
# 4                            4                         1
#
#                             loading_equipment             delivery_modes  \
# 0                                  Carretilla                Motocicleta
# 1                                  Carretilla  No se realizan domicilios
# 2                                     Ninguno  No se realizan domicilios
# 3  Carretilla, Elevador, Escaleras eléctricas  No se realizan domicilios
# 4                                       Bahía  No se realizan domicilios
#
#   daily_delivery_count               online_delivery_modes  \
# 0                    8                         Motocicleta
# 1                    0  No se realizan ventas por internet
# 2                    0                 Vehículo particular
# 3                    1  No se realizan ventas por internet
# 4                    4  No se realizan ventas por internet
#
#   daily_online_delivery_count
# 0                           8
# 1                           0
# 2                           5
# 3                           0
# 4                           1
#
# [5 rows x 38 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           487 non-null    int64
#  1   timestamp                    487 non-null    datetime64[ns]
#  2   email                        474 non-null    object
#  3   company_name                 487 non-null    object
#  4   est_address                  487 non-null    object
#  5   contact_phone                487 non-null    object
#  6   employees                    487 non-null    int64
#  7   has_female_employees         487 non-null    object
#  8   female_employees             445 non-null    float64
#  9   female_percentage            487 non-null    float64
#  10  female_in_distribution       445 non-null    float64
#  11  pct_female_in_distribution   445 non-null    float64
#  12  female_with_contract         445 non-null    float64
#  13  pct_female_with_contract     445 non-null    float64
#  14  female_population_groups     445 non-null    object
#  15  female_support_roles         446 non-null    object
#  16  economic_activity            487 non-null    object
#  17  top_3_activities             487 non-null    object
#  18  main_products                487 non-null    object
#  19  has_warehouse_space          487 non-null    object
#  20  warehouse_count              454 non-null    float64
#  21  warehouse_floor              311 non-null    float64
#  22  warehouse_area_m2            311 non-null    float64
#  23  warehouse_height_m           311 non-null    float64
#  24  warehouse_within_zuap        311 non-null    object
#  25  warehouse_municipality       311 non-null    object
#  26  warehouse_type               311 non-null    object
#  27  supply_day                   487 non-null    object
#  28  supply_frequency_per_week    487 non-null    object
#  29  loading_schedule             487 non-null    object
#  30  unloading_method             487 non-null    object
#  31  safety_perception_motorized  487 non-null    int64
#  32  safety_perception_bicycle    487 non-null    int64
#  33  loading_equipment            483 non-null    object
#  34  delivery_modes               487 non-null    object
#  35  daily_delivery_count         487 non-null    int64
#  36  online_delivery_modes        487 non-null    object
#  37  daily_online_delivery_count  487 non-null    int64
# dtypes: datetime64[ns](1), float64(10), int64(6), object(21)
# memory usage: 144.7+ KB
# original info: None
# Checking unique values in each column:
# employees (36 unique):
# [ 13  12   3  32   4   6   2  14  18   5   7   9   1   8  20  39  11  10
#   24  19 150  27  15  17  30 105  25 153  47  28  26  60  53  48  23  16]
# ----------------------------------------
# has_female_employees (2 unique):
# ['Sí' 'No']
# ----------------------------------------
# female_employees (27 unique):
# [  5.   9.  nan  20.   1.   2.   3.   7.  15.   6.   4.   8.  21.  26.
#   23.  10.  13.  72. 105.  22.  16.  11.  14.  32.  34.  12.  25.]
# ----------------------------------------
# female_percentage (68 unique):
# [0.38461538 0.75       0.         0.625      0.25       0.33333333
#  0.5        0.07142857 0.27777778 1.         0.71428571 0.4
#  0.53846154 0.11111111 0.35       0.66666667 0.54545455 0.45454545
#  0.1        0.8        0.6        0.2        0.875      0.16666667
#  0.125      0.83333333 0.81818182 0.42105263 0.17333333 0.74074074
#  0.7        0.42857143 0.44444444 0.35294118 0.22222222 0.55555556
#  0.63636364 0.76666667 0.92857143 0.68571429 0.57142857 0.52
#  0.68627451 0.06666667 0.46808511 0.3        0.14285714 0.81481481
#  0.375      0.10714286 0.72727273 0.61538462 0.91666667 0.58333333
#  0.23333333 0.64       0.77777778 0.60377358 0.56666667 0.46666667
#  0.26666667 0.70588235 0.85714286 0.3125     0.56       0.89285714
#  0.37037037 0.36363636]
# ----------------------------------------
# female_in_distribution (10 unique):
# [ 0. nan  1.  2.  3.  4.  8.  7.  6.  5.]
# ----------------------------------------
# pct_female_in_distribution (20 unique):
# [0.                nan 0.05       1.         0.33333333 0.5
#  0.06666667 0.16666667 0.2        0.25       0.125      0.4
#  0.14285714 0.44444444 0.66666667 0.23076923 0.15384615 0.07619048
#  0.13333333 0.07142857]
# ----------------------------------------
# female_with_contract (28 unique):
# [  5.   0.  nan  13.   1.   2.   3.   7.  15.   6.   4.   8.  10.   9.
#   26.  20.  23.  72. 105.  18.  22.  11.  16.  32.  34.  12.  14.  25.]
# ----------------------------------------
# pct_female_with_contract (17 unique):
# [1.         0.                nan 0.65       0.5        0.33333333
#  0.66666667 0.47619048 0.4        0.2        0.14285714 0.25
#  0.46153846 0.75       0.81818182 0.125      0.625     ]
# ----------------------------------------
# female_population_groups (18 unique):
# ['Madres cabeza de familia, Migrantes' 'Madres cabeza de familia' nan
#  'Ninguna de las anteriores' 'Víctimas del conflicto armado'
#  'Madres cabeza de familia, Ninguna de las anteriores'
#  'Madres cabeza de familia, Todas las anteriores'
#  'Madres cabeza de familia, Víctimas del conflicto armado' 'Migrantes'
#  'Madres cabeza de familia, Víctimas del conflicto armado, Mujeres transgénero'
#  'Mujeres pertenecientes a grupos étnicos'
#  'Madres cabeza de familia, Migrantes, Víctimas del conflicto armado, Mujeres transgénero'
#  'Mujeres transgénero'
#  'Madres cabeza de familia, Mujeres pertenecientes a grupos étnicos'
#  'Madres cabeza de familia, Mujeres transgénero, Mujeres con movilidad reducida'
#  'Madres cabeza de familia, Mujeres transgénero' 'Todas las anteriores'
#  'Madres cabeza de familia, Migrantes, Víctimas del conflicto armado']
# ----------------------------------------
# female_support_roles (3 unique):
# ['Sí' 'No' nan]
# ----------------------------------------
# economic_activity (93 unique):
# ['Venta al detalle' 'Fabricante Compran terminado y comercializa'
#  'Proveedor'
#  'Proveedor correos ventas en línea Servicios de transporte y distribución de mercancías'
#  'Fabricante'
#  'Venta al detalle Electrodomésticos y hogar Elementos misceláneos'
#  'Venta al detalle Electrodomésticos y hogar'
#  'Venta al detalle correos ventas en línea Servicios de transporte y distribución de mercancías'
#  'Proveedor Elementos misceláneos' 'Venta al detalle Carpintería'
#  'Venta al detalle Venta y compra de carton' 'Ventas por internet'
#  'Venta al detalle Bolsos' 'Venta al detalle Maquinaria'
#  'Venta al detalle Construcción liviana' 'Venta al detalle Maderas'
#  'Venta al detalle Venta de calzado' 'Venta al detalle Madera seca'
#  'Venta al detalle Cigarrería' 'Venta al detalle Imprenta'
#  'Venta al detalle Aglomerados' 'Venta al detalle Madera chingale'
#  'Venta al detalle Decoracion' 'Venta al detalle Madera cruda'
#  'Venta al detalle Pijamad' 'Venta al detalle Producción de alimentos'
#  'Venta al detalle Ropa'
#  'Venta al detalle Confección y moda Venta de productos de belleza'
#  'Venta al detalle joyería' 'Venta al detalle Joyería'
#  'Venta al detalle Joyas y compraventa'
#  'Proveedor Carpintería Marquetería' 'Venta al detalle Bares ocio'
#  'Proveedor Ropa para Hombre y Mujer.'
#  'Venta al detalle Textiles Venta de calzado' 'Venta al detalle Textiles'
#  'ProveedorRopa de cama' 'Proveedor Textiles' 'Venta al detalle Bisutería'
#  'Venta al detalle venta de todo tipo de bolsos'
#  'Ventas por internet Venta de calzado'
#  'Fabricante Carpintería Marquetería'
#  'Venta al detalle Cigarrería Expendio de bebidas alcohólicas'
#  'Fabricante Textiles' 'Fabricante Papelería'
#  'Venta al detalle Elementos misceláneos'
#  'Proveedor accesorios par celulares'
#  'Venta al detalle Confección y moda Textiles'
#  'Venta al detalle Artículos religiosos' 'Fabricante Papelería Publicidad'
#  'Fabricante Litografía'
#  'Venta al detalle correos ventas en línea Ferretería Todo en plásticos y desechables'
#  'Venta al detalle Fabricación (manufacturas) Decoración'
#  'Venta al detalle Materiales eléctricos'
#  'Fabricante Centro de impresiones'
#  'Venta al detalle Bonbilleria lámparas fluorescentes'
#  'Venta al detalle Maquinaria Articulos eléctricos'
#  'Fabricante Fabricación (manufacturas)'
#  'Proveedor Materiales y Eléctricos de Telecomunicaciones'
#  'Venta al detalle Decoración Muebles'
#  'Venta al detalle Cigarrería Supermercados'
#  'Venta al detalle Papelería Perfumería'
#  'Proveedor Fabricación (manufacturas) Decoración'
#  'Fabricante Solo trabajo en cuero' 'Proveedor Carpintería Muebles'
#  'Fabricante Carpintería' 'Venta al detalle Ferretería'
#  'Proveedor Café gurmet venta' 'Venta al detalle Textiles Artesanías'
#  'Proveedor Cigarrería Expendio de bebidas alcohólicas'
#  'Venta al detalle Venta café Gormet' 'Venta al detalle venta y empeño'
#  'Venta al detalle Optica' 'Venta al detalle Ferretería Maquinaria'
#  'Fabricante Servicios de transporte y distribución de mercancías'
#  'Venta al detalle Herrajes de covina'
#  'Venta al detalle correos ventas en línea Servicios de transporte y distribución de mercancías Decoración'
#  'Venta al detalle venta y reparacion de bicicletas.'
#  'Venta al detalle Dotaciones empresariales.'
#  'Venta al detalle Ferretería Venta de productos de belleza'
#  'Venta al detalleRopa de cama' 'Venta al detalleLenceríapara mujer.'
#  'Venta al detalle Ropa para Dama' 'Proveedor Venta muebles peluquería'
#  'Proveedor Silleteria'
#  'Venta al detalle Venta de productos médicos ortopédicos'
#  'Venta al detalle Óptica'
#  'Venta al detalle Textiles Venta uniformes médicos dotación hospitalaria'
#  'Venta al detalle Servicio de venta lentes' 'Proveedor Ferretería'
#  'Proveedor ocio' 'Venta al detalle Gafas' 'FabricanteMercancia de ropa']
# ----------------------------------------
# top_3_activities (239 unique):
# ['Venta de productos de belleza' 'Venta de calzado'
#  'Recolección de residuos'
#  'Fabricación (manufacturas) Compran terminado y comercializa' 'Mecánica'
#  'Textiles' 'Servicios de transporte y distribución de mercancías'
#  'Ropa desportiva'
#  'Mensajería correos ventas en línea Servicios de transporte y distribución de mercancías'
#  'Ferretería' 'Madera' 'Fabricación (manufacturas)' 'Confección y moda'
#  'Decoración Electrodomésticos y hogar Elementos misceláneos' 'Celulares'
#  'Decoración Electrodomésticos y hogar' 'Piñateria' 'drogueria'
#  'cacharreria' 'Marroquineria' 'Maquillaje' 'Farmacia' 'Cafetería'
#  'Lencería' 'Aseo personal y belleza' 'Restaurante' 'Colchoneria'
#  'Electrodomésticos y hogar Elementos misceláneos' 'Cacharreria'
#  'Papelería' 'Tecnología' 'Calzado' 'Recolección de residuos Carpintería'
#  'Juguetes' 'Recolección de residuos Venta y compra de carton'
#  'Producción de alimentos' 'Venta de calzado Bolsos'
#  'Ferretería Maquinaria' 'Decoración Construcción liviana'
#  'Carpintería Maderas' 'Cobijas y toallas'
#  'Confección y moda Venta de calzado' 'Carpintería Madera seca'
#  'Bisuteria' 'Confitería Cigarrería' 'Papelería Imprenta'
#  'Materiales insumos muebles hogar' 'Carpintería Aglomerados'
#  'Carpintería Madera chingale' 'Textiles Decoracion' 'Mascotas'
#  'Servicios de salud' 'Dulceria' 'Perfumería' 'Vitrinas' 'Pijamas'
#  'Carpintería Madera cruda' 'Pasteles horneados' 'Cacharros' 'Ropa'
#  'Elementos misceláneos' 'Ropa de bebe' 'Confección y moda Pijamad'
#  'Parafina y velad' 'Construcción' 'Compraventa'
#  'Venta de materiales de construcción' 'Productos de aseo' 'Esencias'
#  'Gorras' 'Jeans' 'Accesorios celular' 'Electrodomésticos y hogar'
#  'Restaurante Producción de alimentos' 'Venta de calzado Ropa'
#  'Elementos misceláneos Confección y moda Venta de productos de belleza'
#  'Venta de gorras' 'Joyeria' 'Gafas' 'Electrodomésticos y hogar joyería'
#  'Electrodomésticos y hogar Joyería' 'Tienda de mascotas'
#  'Electrodomésticos y hogar Joyas y compraventa' 'Accesorios celulares'
#  'Distribución de valores' 'Ropa para todo tipo de mujer.'
#  'Ropa de hombre y mujer' 'Textiles Venta de calzado'
#  'Ferretería Carpintería Marquetería' 'Producción de alimentos Bares ocio'
#  'Venta de calzado Ropa para Hombre y Mujer.' 'Óptica' 'Ropa de Cama'
#  'Confección y moda Textiles Venta de calzado'
#  'Confección y moda Textiles' 'Confección y modaRopa de cama'
#  'Textiles Bisutería' 'Venta de bolsos'
#  'Confección y moda venta de todo tipo de bolsos'
#  'Fabricación (manufacturas) Carpintería Marquetería' 'Bolsos'
#  'Refrigeración comercial. Punto de Venta.' 'Carpintería'
#  'Servicios de transporte y distribución de mercancías Textiles'
#  'Maquinaria' 'Restaurante Cigarrería Expendio de bebidas alcohólicas'
#  'Sonido' 'Supermercados' 'Fabricación (manufacturas) Textiles'
#  'Reposteria' 'Extenciones ee cabello' 'muebles'
#  'Fabricación (manufacturas) Papelería'
#  'Electrodomésticos y hogar accesorios par celulares'
#  'Elementos misceláneos Confección y moda Textiles'
#  'Decoración Artículos religiosos'
#  'Tienda Naturista y articulos para reposteria y puñateria'
#  'Fabricación (manufacturas) Papelería Publicidad' 'Papelería Litografía'
#  'Telecomunicaciones' 'Articulos religiosos'
#  'Mensajería correos ventas en línea Ferretería Todo en plásticos y desechables'
#  'Venta de materiales de construcción Fabricación (manufacturas) Decoración'
#  'Decoración Materiales eléctricos'
#  'Fabricación (manufacturas) Centro de impresiones'
#  'Ferretería Bonbilleria lámparas fluorescentes'
#  'Venta de materiales de construcción Maquinaria Articulos eléctricos'
#  'Venta de materiales de construcción Fabricación (manufacturas)'
#  'Muebleria' 'Elementos eléctricos'
#  'Ferretería Materiales y Eléctricos de Telecomunicaciones'
#  'Fabricación (manufacturas) Decoración Muebles' 'Envio de paquetes'
#  'Producción de alimentos Cigarrería Supermercados' 'Iluminación'
#  'productos naturales para la belleza' 'Iluminarias'
#  'Elementos misceláneos Papelería Perfumería' 'accesorios celulares'
#  'Fabricación (manufacturas) Solo trabajo en cuero' 'Carnicería'
#  'Ventas de sombrillas' 'Fabricación (manufacturas) Carpintería Muebles'
#  'Fabricación (manufacturas) Carpintería'
#  'Venta de materiales de construcción Ferretería'
#  'Restaurante Café gurmet venta' 'Decoración Textiles Artesanías'
#  'Confitería Cigarrería Expendio de bebidas alcohólicas'
#  'Restaurante Venta café Gormet' 'Compra venta y empeño' 'Litografía'
#  'Artes gráficas' 'Litografia' 'Almacen de diferentes articulos'
#  'Cigarreria' 'Cascos' 'Productos alimenticios  naturales' 'Panaderia'
#  'Repuestos de moto' 'Repuestos para motos' 'Servicios de salud Optica'
#  'Plantas' 'Salsamentaria' 'Confitería saludable' 'Pinturas' 'Vitrina'
#  'Venta de materiales de construcción Ferretería Maquinaria'
#  'Fabricación (manufacturas) Servicios de transporte y distribución de mercancías'
#  'Productos de motos' 'Carpintería Herrajes de covina'
#  'Mensajería correos ventas en línea Servicios de transporte y distribución de mercancías Decoración'
#  'Entra y reparación de teléfono'
#  'Distribucion venta y reparacion de bicicletas.'
#  'Confección y moda Dotaciones empresariales.'
#  'Electrodomésticos y hogar Ferretería Venta de productos de belleza'
#  'Restaurante Cigarrería' 'Compra y venta de artículos'
#  'LenceríaRopa de cama' 'Confección y modaLenceríapara mujer.'
#  'Confección y moda Ropa para Dama' 'Elementos ortopédicos'
#  'Venta de productos de belleza Venta muebles peluquería'
#  'Servicios de transporte y distribución de mercancías Silleteria'
#  'Servicios de salud Venta de productos médicos ortopédicos'
#  'Servicios de salud Óptica'
#  'Confección y moda Textiles Venta uniformes médicos dotación hospitalaria'
#  'Servicios de salud Servicio de venta lentes' 'Compraventa de artículos'
#  'Elementos misceláneos Venta de calzado'
#  'Confitería Cigarrería Supermercados' 'Bares ocio' 'Maletas' 'Merxancia'
#  'Tecnologia - accesorios' 'Mercancia Ropa en general'
#  'Venta de lentes con formula médica.'
#  'Ventas de lentes por formula médica'
#  'Ventas de lentes con formula médica' 'Servicios de salud Gafas'
#  'Piñateria y jugueteria' 'Productos de hogar'
#  'Venta de material electrico' 'Estructuras MetálicasMercancia de ropa'
#  'Accesorios de celulares' 'Salsamentaria- cantina y abarrotes'
#  'RELOJERIA' 'Mensajería, correos, ventas en línea' 'CREDITOS'
#  'Confección y moda, Textiles' 'Accesorios para celular' 'Tecnologia'
#  'Elementos misceláneos, Papelería' 'Accesorios de tecnología'
#  'Electrodomésticos y hogar, Elementos misceláneos, Venta de productos de belleza'
#  'Sombreros' 'piñateria' 'Administración de asociación Aparca'
#  'Venta de productos de belleza, Accesorios para celular'
#  'Confección y moda, Venta de calzado' 'Belleza'
#  'Decoración, Elementos misceláneos' 'Zapatos'
#  'Fabricación (manufacturas), Confección y moda, Textiles'
#  'Ropa deportivo' 'Mensajería' 'Mensajeria' 'Venta de ropa' 'De todo'
#  'Productos varios que distribuyen al centro' 'Lociones'
#  'Elementos misceláneos, Papelería y oficina'
#  'Ferretería, Elementos misceláneos' 'Parqueadero' 'Mensajería y envio'
#  'Elementos misceláneos, Cigarrería, Juguetería Linterna'
#  'Logística de operaciones' 'Aseo personal,bebes, miscelánea'
#  'Ferretería, Cigarrería, Cacharro' 'Servicio bancarios']
# ----------------------------------------
# main_products (34 unique):
# ['Cosméticos y productos de belleza' 'Calzado' 'Reciclaje y residuos'
#  'Manufacturas' 'Mecánica' 'Moda y textiles' 'Mensajería' 'Ferretería'
#  'Maderas' 'Artículos para el hogar' 'Electrónica'
#  'Juguetería y elementos deportivos' 'Cacao, chocolate y confitería'
#  'Productos médicos y de salud' 'Café' 'Restauración' 'Electrodomésticos'
#  'Papelería' 'Productos alimenticios' 'Materiales de construcción'
#  'Productos veterinarios y mascotas' 'Muebles de oficina' 'Compraventa'
#  'Productos de aseo' 'Joyas' 'Servicios financieros' 'Refrigeración'
#  'Maquinaria' 'Servicios de telecomunicaciones' 'Productos cárnicos'
#  'Arte y materiales para el arte' 'Bares y ocio'
#  'Servicio de estacionamiento' 'Suministros']
# ----------------------------------------
# has_warehouse_space (5 unique):
# ['Interno' 'No' 'Externo, propio' 'Externo, alquilado'
#  'Externo, compartido con otros comercios']
# ----------------------------------------
# warehouse_count (17 unique):
# [  1.  40.   0.   2.   5.   4.   3.  20.  10.  50.  31.  30. 240.  17.
#  100.  nan   8.]
# ----------------------------------------
# warehouse_floor (13 unique):
# [ 2.  4.  1. nan  3.  9.  5. 11. 14.  7. -1. 17. 12.]
# ----------------------------------------
# warehouse_area_m2 (68 unique):
# [5.00e+01 1.50e+02 1.30e+02 2.00e+02 2.50e+01      nan 4.00e+01 2.30e+02
#  1.00e+01 3.40e+02 2.00e+01 3.50e+02 1.00e+00 5.00e+00 6.00e+01 1.00e+02
#  3.00e+01 1.50e+01 1.20e+02 1.20e+01 1.60e+02 1.10e+02 2.56e+02 2.50e+02
#  1.36e+02 8.00e+01 2.50e+03 3.00e+00 7.00e+01 8.00e+00 3.00e+02 3.80e+02
#  8.80e+01 2.20e+02 6.40e+01 7.00e+00 6.00e+00 2.40e+01 4.80e+01 3.20e+02
#  4.00e+00 2.00e+00 1.20e+03 1.60e+01 8.00e+02 6.50e+01 3.20e+01 2.10e+01
#  4.00e+02 9.00e+01 5.00e+02 8.90e+01 9.00e+00 1.40e+01 1.80e+01 4.15e+00
#  3.50e+01 1.96e+02 1.02e+02 5.40e+01 4.50e+02 1.76e+02 2.40e+02 2.90e+02
#  1.40e+02 1.70e+02 6.00e+02 3.60e+02]
# ----------------------------------------
# warehouse_height_m (17 unique):
# [ 3.   1.5  4.   nan  5.   2.   8.  10.   2.2  1.   6.   3.2  4.5  2.5
#   2.1  3.5  7. ]
# ----------------------------------------
# warehouse_within_zuap (3 unique):
# ['Sí' nan 'No']
# ----------------------------------------
# warehouse_municipality (5 unique):
# ['Medellín' nan 'La Estrella' 'Bogota D.C.' 'Caldas']
# ----------------------------------------
# warehouse_type (5 unique):
# ['Almacenamiento de inventarios' 'Recepción de mercancías' 'Otro ¿cuál?'
#  nan 'Cuartos fríos']
# ----------------------------------------
# supply_day (45 unique):
# ['Lunes, Martes, Miércoles, Jueves, Viernes'
#  'Lunes, Martes, Miércoles, Jueves, Viernes, Sábado'
#  'Lunes, Martes, Miércoles, Jueves, Viernes, Sábado, Domingo, Festivos'
#  'Lunes' 'Lunes, Martes' 'Miércoles' 'Martes, Miércoles, Jueves' 'Martes'
#  'Lunes, Jueves' 'Lunes, Jueves, Viernes' 'Jueves, Viernes'
#  'Lunes, Viernes' 'Lunes, Martes, Miércoles, Jueves'
#  'Lunes, Miércoles, Viernes' 'Jueves' 'Lunes, Viernes, Sábado'
#  'Lunes, Miércoles, Jueves, Viernes, Sábado' 'Lunes, Jueves, Sábado'
#  'Martes, Jueves' 'Viernes' 'Lunes, Martes, Viernes, Sábado' 'Sábado'
#  'Martes, Miércoles, Sábado' 'Miércoles, Jueves' 'Lunes, Miércoles'
#  'Lunes, Martes, Miércoles, Jueves, Viernes, Sábado, Domingo'
#  'Miércoles, Sábado' 'Miércoles, Viernes' 'Martes, Sábado'
#  'Martes, Viernes' 'Jueves, Sábado' 'Martes, Jueves, Viernes'
#  'Martes, Miércoles, Jueves, Viernes' 'Lunes, Martes, Miércoles, Sábado'
#  'Lunes, Miércoles, Sábado' 'Lunes, Martes, Sábado'
#  'Martes, Miércoles, Jueves, Sábado' 'Lunes, Martes, Viernes'
#  'Lunes, Miércoles, Jueves' 'Lunes, Miércoles, Jueves, Viernes'
#  'Miércoles, Jueves, Sábado' 'Martes, Miércoles'
#  'Lunes, Martes, Miércoles' 'Domingo' 'Lunes, Martes, Miércoles, Viernes']
# ----------------------------------------
# supply_frequency_per_week (8 unique):
# [5 '6 o más' '1 vez por semana' 2 3 'La periodicidad es mensual' 4
#  'La periodicidad es quincenal']
# ----------------------------------------
# loading_schedule (122 unique):
# ['08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00'
#  '10:00 a 11:00, 14:00 a 15:00, 16:00 a 17:00' '09:00 a 10:00'
#  '08:00 a 09:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '07:00 a 08:00, 08:00 a 09:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00, 19:00 a 20:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '20:00 a 21:00' '08:00 a 09:00, 19:00 a 20:00'
#  '08:00 a 09:00, 17:00 a 18:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 15:00 a 16:00, 16:00 a 17:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00'
#  '08:00 a 09:00, 09:00 a 10:00' '06:00 a 07:00, 07:00 a 08:00'
#  '15:00 a 16:00' '07:00 a 08:00, 17:00 a 18:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00'
#  '17:00 a 18:00' '10:00 a 11:00, 17:00 a 18:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00'
#  '08:00 a 09:00, 11:00 a 12:00' '08:00 a 09:00, 18:00 a 19:00'
#  '08:00 a 09:00, 16:00 a 17:00' '07:00 a 08:00, 18:00 a 19:00'
#  '05:00 a 06:00, 17:00 a 18:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00'
#  '12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00'
#  '07:00 a 08:00, 08:00 a 09:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00'
#  '08:00 a 09:00, 14:00 a 15:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '09:00 a 10:00, 15:00 a 16:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 17:00 a 18:00, 18:00 a 19:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 18:00 a 19:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '10:00 a 11:00'
#  '13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00'
#  '08:00 a 09:00, 12:00 a 13:00' '08:00 a 09:00, 13:00 a 14:00'
#  '10:00 a 11:00, 11:00 a 12:00' '08:00 a 09:00, 15:00 a 16:00'
#  '08:00 a 09:00, 12:00 a 13:00, 17:00 a 18:00'
#  '08:00 a 09:00, 09:00 a 10:00, 11:00 a 12:00, 13:00 a 14:00, 14:00 a 15:00'
#  '04:00 a 05:00' '06:00 a 07:00' '14:00 a 15:00' '11:00 a 12:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00'
#  '16:00 a 17:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '12:00 a 13:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00, 19:00 a 20:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00'
#  '09:00 a 10:00, 17:00 a 18:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00'
#  '19:00 a 20:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00'
#  '09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 16:00 a 17:00, 17:00 a 18:00'
#  '13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00'
#  '14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 15:00 a 16:00, 16:00 a 17:00'
#  '10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00'
#  '12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '01:00 a 02:00, 02:00 a 03:00, 03:00 a 04:00, 04:00 a 05:00'
#  '11:00 a 12:00, 12:00 a 13:00'
#  '05:00 a 06:00, 10:00 a 11:00, 16:00 a 17:00'
#  '10:00 a 11:00, 12:00 a 13:00, 15:00 a 16:00, 17:00 a 18:00'
#  '01:00 a 02:00' '08:00 a 09:00, 11:00 a 12:00, 18:00 a 19:00'
#  '04:00 a 05:00, 07:00 a 08:00, 12:00 a 13:00'
#  '03:00 a 04:00, 07:00 a 08:00, 11:00 a 12:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00'
#  '09:00 a 10:00, 14:00 a 15:00, 18:00 a 19:00'
#  '07:00 a 08:00, 09:00 a 10:00, 13:00 a 14:00, 18:00 a 19:00'
#  '09:00 a 10:00, 13:00 a 14:00, 15:00 a 16:00'
#  '09:00 a 10:00, 12:00 a 13:00, 16:00 a 17:00'
#  '08:00 a 09:00, 10:00 a 11:00'
#  '03:00 a 04:00, 05:00 a 06:00, 07:00 a 08:00, 10:00 a 11:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '04:00 a 05:00, 07:00 a 08:00, 12:00 a 13:00, 16:00 a 17:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '13:00 a 14:00, 16:00 a 17:00'
#  '07:00 a 08:00, 08:00 a 09:00, 15:00 a 16:00, 16:00 a 17:00'
#  '05:00 a 06:00, 06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '10:00 a 11:00, 12:00 a 13:00, 15:00 a 16:00'
#  '07:00 a 08:00, 08:00 a 09:00, 14:00 a 15:00'
#  '08:00 a 09:00, 10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00'
#  '05:00 a 06:00' '07:00 a 08:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '14:00 a 15:00, 15:00 a 16:00'
#  '11:00 a 12:00, 12:00 a 13:00, 15:00 a 16:00, 22:00 a 23:00'
#  '10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00, 17:00 a 18:00'
#  '10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00'
#  '10:00 a 11:00, 12:00 a 13:00, 16:00 a 17:00'
#  '18:00 a 19:00, 19:00 a 20:00, 20:00 a 21:00'
#  '11:00 a 12:00, 13:00 a 14:00, 15:00 a 16:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 14:00 a 15:00'
#  '08:00 a 09:00, 09:00 a 10:00, 13:00 a 14:00, 14:00 a 15:00'
#  '09:00 a 10:00, 11:00 a 12:00, 12:00 a 13:00, 15:00 a 16:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '06:00 a 07:00, 19:00 a 20:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00, 19:00 a 20:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '05:00 a 06:00, 06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00']
# ----------------------------------------
# unloading_method (71 unique):
# ['En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En carreta "zorrilla"'
#  'En carreta "zorrilla"' 'En camión, sobre la vía, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora'
#  'En camión, sobre la vía, En motocicleta' 'En vehículo particular'
#  'En camión, se descarga internamente' 'En camión, sobre la vía'
#  'En camión, sobre la vía, En camión, sobre el andén'
#  'En carreta "zorrilla", En vehículo particular' 'En motocicleta'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En carreta "zorrilla"'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa'
#  'En camión, se descarga internamente, En motocicleta, En bicicleta, En carreta "zorrilla", En vehículo particular'
# ...
#  '09:00 a 10:00, 14:00 a 15:00, 18:00 a 19:00'
#  '07:00 a 08:00, 09:00 a 10:00, 13:00 a 14:00, 18:00 a 19:00'
#  '09:00 a 10:00, 13:00 a 14:00, 15:00 a 16:00'
#  '09:00 a 10:00, 12:00 a 13:00, 16:00 a 17:00'
#  '08:00 a 09:00, 10:00 a 11:00'
#  '03:00 a 04:00, 05:00 a 06:00, 07:00 a 08:00, 10:00 a 11:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00'
#  '04:00 a 05:00, 07:00 a 08:00, 12:00 a 13:00, 16:00 a 17:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '13:00 a 14:00, 16:00 a 17:00'
#  '07:00 a 08:00, 08:00 a 09:00, 15:00 a 16:00, 16:00 a 17:00'
#  '05:00 a 06:00, 06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '10:00 a 11:00, 12:00 a 13:00, 15:00 a 16:00'
#  '07:00 a 08:00, 08:00 a 09:00, 14:00 a 15:00'
#  '08:00 a 09:00, 10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00'
#  '05:00 a 06:00' '07:00 a 08:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '14:00 a 15:00, 15:00 a 16:00'
#  '11:00 a 12:00, 12:00 a 13:00, 15:00 a 16:00, 22:00 a 23:00'
#  '10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00, 17:00 a 18:00'
#  '10:00 a 11:00, 13:00 a 14:00, 15:00 a 16:00'
#  '10:00 a 11:00, 12:00 a 13:00, 16:00 a 17:00'
#  '18:00 a 19:00, 19:00 a 20:00, 20:00 a 21:00'
#  '11:00 a 12:00, 13:00 a 14:00, 15:00 a 16:00'
#  '08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 14:00 a 15:00'
#  '08:00 a 09:00, 09:00 a 10:00, 13:00 a 14:00, 14:00 a 15:00'
#  '09:00 a 10:00, 11:00 a 12:00, 12:00 a 13:00, 15:00 a 16:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00'
#  '06:00 a 07:00, 19:00 a 20:00'
#  '07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00, 11:00 a 12:00, 12:00 a 13:00, 13:00 a 14:00, 14:00 a 15:00, 15:00 a 16:00, 16:00 a 17:00, 17:00 a 18:00, 18:00 a 19:00, 19:00 a 20:00'
#  '06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00, 09:00 a 10:00, 10:00 a 11:00'
#  '05:00 a 06:00, 06:00 a 07:00, 07:00 a 08:00, 08:00 a 09:00']
# ----------------------------------------
# unloading_method (71 unique):
# ['En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En carreta "zorrilla"'
#  'En carreta "zorrilla"' 'En camión, sobre la vía, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora'
#  'En camión, sobre la vía, En motocicleta' 'En vehículo particular'
#  'En camión, se descarga internamente' 'En camión, sobre la vía'
#  'En camión, sobre la vía, En camión, sobre el andén'
#  'En carreta "zorrilla", En vehículo particular' 'En motocicleta'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En carreta "zorrilla"'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa'
#  'En camión, se descarga internamente, En motocicleta, En bicicleta, En carreta "zorrilla", En vehículo particular'
#  'En camión, se descarga internamente, En motocicleta, En bicicleta, En carreta "zorrilla"'
#  'En camión, sobre el andén, En carreta "zorrilla"'
#  'En motocicleta, En carreta "zorrilla"'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, sobre la vía'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En motocicleta, En carreta "zorrilla"'
#  'En camión, se descarga internamente, En camión, estacionado en bahía y la ingresa el personal de mi empresa'
#  'En camión, se descarga internamente, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, sobre la vía, En motocicleta, En carreta "zorrilla"'
#  'En camión, en vías aledañas, En carreta "zorrilla"' 'En bicicleta'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En vehículo particular'
#  'En camión, sobre el andén'
#  'En camión, sobre la vía, En motocicleta, En bicicleta, En vehículo particular'
#  'En camión, sobre la vía, En vehículo particular'
#  'En camión, en vías aledañas, En carreta "zorrilla", En vehículo particular'
#  'En motocicleta, En vehículo particular'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, estacionado en parqueadero propiedad de un tercero, En vehículo particular'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, estacionado en parqueadero propiedad de un tercero, En carreta "zorrilla"'
#  'En camión, se descarga internamente, En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, en vías aledañas, En carreta "zorrilla", En vehículo particular'
#  'En camión, estacionado en parqueadero propiedad de un tercero'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En vehículo particular'
#  'En motocicleta, En bicicleta, En carreta "zorrilla"'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En motocicleta, En vehículo particular'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En carreta "zorrilla", En vehículo particular'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En motocicleta'
#  'En motocicleta, En carreta "zorrilla", En vehículo particular'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía, En camión, sobre el andén, En camión, en vías aledañas'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía, En camión, sobre el andén, En camión, en vías aledañas, En camión, estacionado en parqueadero propiedad de un tercero, En motocicleta, En bicicleta, En carreta "zorrilla", En vehículo particular'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En motocicleta'
#  'En camión, estacionado en parqueadero propiedad de un tercero, En carreta "zorrilla"'
#  'En camión, en vías aledañas, En motocicleta, En carreta "zorrilla"'
#  'En motocicleta, En bicicleta' 'En camión, en vías aledañas'
#  'En camión, sobre la vía, En bicicleta, En carreta "zorrilla"'
#  'En bicicleta, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En carreta "zorrilla", En vehículo particular'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En motocicleta, En carreta "zorrilla"'
#  'En motocicleta, En bicicleta, En vehículo particular'
#  'En motocicleta, En carreta "zorrilla",En vehículo particular'
#  'En motocicleta,En vehículo particular'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, sobre el andén'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía, En motocicleta, En carreta "zorrilla"'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa,En vehículo particular'
#  'En camión, sobre la vía, En camión, sobre el andén, En camión, en vías aledañas, En motocicleta, En carreta "zorrilla",En vehículo particular'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre el andén, En camión, en vías aledañas, En camión, estacionado en parqueadero propiedad de un tercero, En carreta "zorrilla"'
#  'En camión, sobre la vía, En camión, en vías aledañas'
#  'En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía, En carreta "zorrilla"'
#  'En camión, se descarga internamente, En camión, estacionado en bahía y la ingresa el personal de mi empresa, En camión, sobre la vía, En camión, en vías aledañas'
#  'En camión, sobre la vía, En camión, en vías aledañas, En carreta "zorrilla"'
#  'En camión, sobre la vía, En camión, sobre el andén, En carreta "zorrilla"'
#  'En camión, sobre la vía, En motocicleta,En vehículo particular'
#  'En carreta "zorrilla",En vehículo particular'
#  'En camión, se descarga internamente, En motocicleta, En carreta "zorrilla"'
#  'En camión, estacionado en zona bahía y la ingresa la empresa transportadora, En camión, en vías aledañas, En carreta "zorrilla"'
#  'En camión, se descarga internamente, En motocicleta, En carreta "zorrilla",En vehículo particular']
# ----------------------------------------
# safety_perception_motorized (5 unique):
# [2, 3, 5, 4, 1]
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]
# ----------------------------------------
# safety_perception_bicycle (5 unique):
# [1, 3, 2, 4, 5]
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]
# ----------------------------------------
# loading_equipment (56 unique):
# ['Carretilla' 'Ninguno' 'Carretilla, Elevador, Escaleras eléctricas'
#  'Bahía' 'Ninguna' 'Caminata' 'No' 'Carretilla, No' 'no' '1'
#  'Carretilla, Elevador' 'Carretilla, Na' 'Carretilla, 1' 'Camina'
#  'Rampa mecánica' 'Carretilla, Rampa fija' 'Rampa fija'
#  'Carretilla, Parqueadero de uso interno' 'Al hombro' 'No tiene ninguna'
#  'Parqueadero de uso interno' 'Carretilla, Rampa mecánica, Rampa fija'
#  'Rampa fija, Parqueadero de uso interno' 'ninguno'
#  'Carretilla, Descargue a mano' 'Porta doble' 'Elevador, Rampa fija'
#  'no posee' 'Elevador' 'no tiene ninguna' 'Carretilla, Personal externo'
#  'Carretilla, Gato hidráulico'
#  'Carretilla, Elevador, Rampa fija, Porta doble, Parqueadero de uso interno, Parqueadero para clientes'
#  'A mano' 'La misma persona la carga en sus manos'
#  'Rampa mecánica, No hay bodega' 'Las personas lo llevan cargados'
#  'Ninguno se hace en bolsa Acarreo' 'No se requiere por el volumen'
#  'Carretilla, Rampa fija, Parqueadero de uso interno' 'Ninguno anteriores'
#  'No hay bodega' 'Carretilla, Montacargas' 'nan' 'No aplica' 'Escalas'
#  'No es necesario entra oaquete manual'
#  'No se requiere lis paquetes vson pequeños sebtraen a mano' 'Na' 'Ningún'
#  'Caminando' 'Carretilla entra' 'Cajas' 'NINGUNO' 'NINGUNA' 'Ninguni']
# ----------------------------------------
# delivery_modes (54 unique):
# ['Motocicleta' 'No se realizan domicilios' 'Furgón, Carreta "zorrilla"'
#  'Carreta "zorrilla"' 'Caminata, Motocicleta'
#  'Motocicleta, Vehículo particular' 'Caminata'
#  'Motocicleta, Carreta "zorrilla"'
#  'Motocicleta, Vehículo particular, Carreta "zorrilla"' '1' 'Furgón'
#  'Van, Furgón, Carreta "zorrilla"' 'Vehículo particular'
#  'Motocicleta, Furgón, Carreta "zorrilla"'
#  'Motocicleta, Vehículo particular, Van' 'Van'
#  'Caminata, Carreta "zorrilla"' 'Vehículo particular, Carreta "zorrilla"'
#  'Carro particular' 'Motocicleta, Furgón' 'No se realizan domicilios, Van'
#  'Motocicleta, Van' 'No se realizan domicilios, Motocarga gasolina'
#  'Motocicleta, Transportadora' 'No se realizan domicilios, Motocicleta'
#  'No se realizan domicilios, Caminata'
#  'Caminata, Motocicleta, Vehículo particular' 'Motocicleta, Van, Furgón'
#  'Van, Furgón, Empresa transportadora' 'Van, Furgón, Transportadora'
#  'Van, Carreta "zorrilla"' 'Servicio de mensajería' 'Van, Furgón'
#  'Servicios de mensajería' 'Camioneta'
#  'Carreta "zorrilla", Transportadora' 'Caminata, Bicicleta normal'
#  'Vehículo particular, Furgón' 'Bicicleta normal, Motocicleta'
#  'Caminata, Motocicleta, Furgón, Carreta "zorrilla"'
#  'Caminata, Vehículo particular' 'Caminata, Bicicleta de carga'
#  'No aplica' 'No se hacen envíos' 'Vehículo particular, Van' 'Na'
#  'NINGUNO'
#  'Caminata, Vehículo particular, Carreta "zorrilla", Transportadora'
#  'Motocicleta, Trasnportadora' 'Motocicleta, Transportadoras'
#  'Transportadoras' 'Ninguno' 'Motocicleta, Mensajeria contratada'
#  'Caminata, Motocicleta, Vehículo particular, Van']
# ----------------------------------------
# daily_delivery_count (23 unique):
# [  8   0   1   4   6   2 100   3  12   5  32  10  15  20  25   7   9  80
#  200  14  30  50  13]
# ----------------------------------------
# online_delivery_modes (60 unique):
# ['Motocicleta' 'No se realizan ventas por internet' 'Vehículo particular'
#  'Vehículo particular, Furgón, Carreta "zorrilla"'
#  'Si se realizan ventas por internet'
#  'Motocicleta, Vehículo particular, Van'
#  'Caminata, Motocicleta, Vehículo particular, Carreta "zorrilla"'
#  'Motocicleta, Vehículo particular' 'Caminata' 'Caminata, Van' 'Mostrador'
#  '1' 'Motocicleta, Carreta "zorrilla"'
#  'Motocicleta, Vehículo particular, Van, Furgón' 'No' 'Van'
#  'Cliente recoje en negocio' 'No se realiza' 'Motocicleta, Furgón'
#  'Motocicleta, Van, Furgón' 'Van, Carreta "zorrilla"' 'Furgón'
#  'Motocicleta, Van' 'Bicicleta normal, Carreta "zorrilla"'
#  'Transportadora' 'Caminata, Motocicleta, Van, Furgón'
#  'Caminata, Motocicleta' 'Van, Empresa transportadora'
#  'Van, Furgón, Transportadora' 'Transportadoras'
#  'Realizan venta por Internet, cliente recoge' 'Servicio de mensajería'
#  'Carreta "zorrilla"'
#  'No se realizan ventas por internet, Carreta "zorrilla"' 'Van, Furgón'
#  'Camioneta'
#  'Caminata, Bicicleta de carga, Motocicleta, Vehículo particular, Van, Furgón, Carreta "zorrilla"'
#  'Furgón, Carreta "zorrilla"' 'Caminata, Bicicleta normal' '15'
#  'Caminata, Motocicleta, Furgón' 'Caminata, Vehículo particular'
#  'Caminata, Carreta "zorrilla"'
#  'No se realizan ventas por internet, Caminata, Motocicleta'
#  'Servicios de mensajería' 'Ninguna' 'Novse hace envíos'
#  'Vehículo particular, Van' 'Bicicleta de carga, Vehículo particular, Van'
#  'Na' 'Vehículo particular, Furgón' 'NINGUNO'
#  'Motocicleta, Van, Furgón, Carreta "zorrilla"'
#  'Caminata, Motocicleta, Vehículo particular, Transportadora'
#  'Motocicleta, Trnasportadora' 'Motocicleta, Transportadoras'
#  'Motocicleta, Vehículo particular, Van, Furgón, Carreta "zorrilla"'
#  'Motocicleta, Vehículo particular, Rappifavor'
#  'Motocicleta, Mensajería contratada'
#  'Caminata, Motocicleta, Vehículo particular, Van']
# ----------------------------------------
# daily_online_delivery_count (24 unique):
# [  8   0   5   1   6  70   3   9  20   2  23   4  32  10  12  25 300   7
#  200  14  15 100  30  13]
# ----------------------------------------
# supply_frequency_num (3 unique):
# [6, 1, 2]
# Categories (4, int64): [1 < 2 < 5 < 6]
# ----------------------------------------
# warehouse_within_zuap (unique): ['yes', '', 'no']
# Categories (3, object): ['', 'no', 'yes']
# Normalized main_products (unique): ['cosmeticos y productos de belleza', 'calzado', 'reciclaje y residuos', 'manufacturas', 'mecanica', ..., 'productos carnicos', 'arte y materiales para el arte', 'bares y ocio', 'servicio de estacionamiento', 'suministros']
# Length: 34
# Categories (34, object): ['arte y materiales para el arte', 'articulos para el hogar', 'bares y ocio', 'cacao, chocolate y confiteria', ..., 'servicio de estacionamiento', 'servicios de telecomunicaciones', 'servicios financieros', 'suministros']
# Last df_clean                              economic_activity         econ_main  \
# 0                             Venta al detalle  Venta al detalle
# 1                             Venta al detalle  Venta al detalle
# 2                             Venta al detalle  Venta al detalle
# 3  Fabricante Compran terminado y comercializa        Fabricante
# 4                                    Proveedor         Proveedor
#
#                           econ_sub1 econ_sub2
# 0                               NaN       NaN
# 1                               NaN       NaN
# 2                               NaN       NaN
# 3  Compran terminado y comercializa       NaN
# 4                               NaN       NaN

# %%
print("df_clean shape:", df_clean.shape)
print(df_clean.columns.tolist())
print(df_clean.head())
print("original info:", df_clean.info())
# Out:
# df_clean shape: (487, 42)
# ['id', 'timestamp', 'email', 'company_name', 'est_address', 'contact_phone', 'employees', 'has_female_employees', 'female_employees', 'female_percentage', 'female_in_distribution', 'pct_female_in_distribution', 'female_with_contract', 'pct_female_with_contract', 'female_population_groups', 'female_support_roles', 'economic_activity', 'top_3_activities', 'main_products', 'has_warehouse_space', 'warehouse_count', 'warehouse_floor', 'warehouse_area_m2', 'warehouse_height_m', 'warehouse_within_zuap', 'warehouse_municipality', 'warehouse_type', 'supply_day', 'supply_frequency_per_week', 'loading_schedule', 'unloading_method', 'safety_perception_motorized', 'safety_perception_bicycle', 'loading_equipment', 'delivery_modes', 'daily_delivery_count', 'online_delivery_modes', 'daily_online_delivery_count', 'supply_frequency_num', 'econ_main', 'econ_sub1', 'econ_sub2']
#    id               timestamp                                     email  \
# 0   1 2022-05-17 11:20:36.160      Gestiohumana@111tiendasdebelleza.com
# 1   2 2022-05-18 11:17:48.282   CalzadobucaramangaMedellín2@hotmail.com
# 2   3 2022-05-18 08:28:01.487                                 No aplica
# 3   4 2022-05-16 16:22:43.406  comercializadoracentermedmatur@gmail.com
# 4   5 2022-05-16 15:54:14.360                       pipemotos@gmail.com
#
#                            company_name                est_address  \
# 0     Iversiones111t tiendas de belleza  CL 48 54 43 local 102 108
# 1  Distri zapatos - calzado bucaramanga                 Cr 54 4803
# 2                       Molina y arango            Calle 44a 54 32
# 3               Comercializadora center             Calle 46 53 05
# 4                            Pipe motos          Calle  45 53 A 12
#
#          contact_phone  employees has_female_employees  female_employees  \
# 0              5110950         13                   Sí               5.0
# 1           3147907153         12                   Sí               9.0
# 2           3103978026          3                   No               NaN
# 3              5134081         32                   Sí              20.0
# 4  5898256 -3295338608          3                   No               NaN
#
#    female_percentage  ...  safety_perception_bicycle  \
# 0           0.384615  ...                          1
# 1           0.750000  ...                          3
# 2           0.000000  ...                          1
# 3           0.625000  ...                          1
# 4           0.000000  ...                          1
#
#                             loading_equipment             delivery_modes  \
# 0                                  Carretilla                Motocicleta
# 1                                  Carretilla  No se realizan domicilios
# 2                                     Ninguno  No se realizan domicilios
# 3  Carretilla, Elevador, Escaleras eléctricas  No se realizan domicilios
# 4                                       Bahía  No se realizan domicilios
#
#    daily_delivery_count               online_delivery_modes  \
# 0                     8                         Motocicleta
# 1                     0  No se realizan ventas por internet
# 2                     0                 Vehículo particular
# 3                     1  No se realizan ventas por internet
# 4                     4  No se realizan ventas por internet
#
#   daily_online_delivery_count supply_frequency_num         econ_main  \
# 0                           8                  NaN  Venta al detalle
# 1                           0                    6  Venta al detalle
# 2                           5                    6  Venta al detalle
# 3                           0                  NaN        Fabricante
# 4                           1                    1         Proveedor
#
#                           econ_sub1 econ_sub2
# 0                               NaN       NaN
# 1                               NaN       NaN
# 2                               NaN       NaN
# 3  Compran terminado y comercializa       NaN
# 4                               NaN       NaN
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           487 non-null    int64
#  1   timestamp                    487 non-null    datetime64[ns]
#  2   email                        474 non-null    category
#  3   company_name                 487 non-null    category
#  4   est_address                  487 non-null    category
#  5   contact_phone                487 non-null    category
#  6   employees                    487 non-null    int64
#  7   has_female_employees         487 non-null    object
#  8   female_employees             445 non-null    float64
#  9   female_percentage            487 non-null    float64
#  10  female_in_distribution       445 non-null    float64
#  11  pct_female_in_distribution   445 non-null    float64
#  12  female_with_contract         445 non-null    float64
#  13  pct_female_with_contract     445 non-null    float64
#  14  female_population_groups     487 non-null    object
#  15  female_support_roles         446 non-null    category
#  16  economic_activity            487 non-null    category
#  17  top_3_activities             487 non-null    object
#  18  main_products                487 non-null    category
#  19  has_warehouse_space          487 non-null    category
#  20  warehouse_count              454 non-null    float64
#  21  warehouse_floor              311 non-null    category
#  22  warehouse_area_m2            311 non-null    float64
#  23  warehouse_height_m           311 non-null    float64
#  24  warehouse_within_zuap        487 non-null    category
#  25  warehouse_municipality       311 non-null    category
#  26  warehouse_type               311 non-null    category
#  27  supply_day                   487 non-null    object
#  28  supply_frequency_per_week    487 non-null    object
#  29  loading_schedule             487 non-null    object
#  30  unloading_method             487 non-null    object
#  31  safety_perception_motorized  487 non-null    category
#  32  safety_perception_bicycle    487 non-null    category
#  33  loading_equipment            487 non-null    object
#  34  delivery_modes               487 non-null    object
#  35  daily_delivery_count         487 non-null    int64
#  36  online_delivery_modes        487 non-null    object
#  37  daily_online_delivery_count  487 non-null    int64
#  38  supply_frequency_num         260 non-null    category
#  39  econ_main                    487 non-null    category
#  40  econ_sub1                    97 non-null     category
#  41  econ_sub2                    28 non-null     category
# dtypes: category(18), datetime64[ns](1), float64(9), int64(4), object(10)
# memory usage: 181.4+ KB
# original info: None

# %%
    
# 5. Explode Multi‐Label Fields → One‐Hot
#    5.1 Define translation maps for each multi‐label column
DAY_EN = {
    "lunes": "monday", "martes": "tuesday", "miercoles": "wednesday",
    "miércoles": "wednesday", "jueves": "thursday", "viernes": "friday",
    "sabado": "saturday", "sábado": "saturday", "domingo": "sunday",
    "festivos": "holidays",
}
DMODE_EN = {
    "bicicleta": "Bicycle", "bicicleta normal": "Bicycle", "bicicleta de carga": "Bicycle",
    "camion": "Truck", "camión": "Truck", "furgon": "Truck", "van": "Truck",
    "carreta": "Handcart", 'carreta "zorrilla"': "Handcart",
    "motocicleta": "Motorcycle", "motocarga": "Motorcycle",
    "vehiculo particular": "Private Vehicle", "carro particular": "Private Vehicle",
    "no se realizan domicilios": "no_home_delivery",
    "no se hacen envios": "no_home_delivery",
    "no se realizan ventas por internet": "no_ecommerce",
    "si se realizan ventas por internet": "yes_ecommerce",
}
UNLOAD_EN = {
    "estacionado en zona bahia": "Loading/unloading zone",
    "bahia": "Loading/unloading zone",
    "internamente": "Establishment facilities",
    "se descarga internamente": "Establishment facilities",
    "parqueadero": "Parking lot",
    "sobre el anden": "On the sidewalk",
    "sobre la via": "On the road",
    "en vias aledanas": "Nearby roads",
}
EQUIP_EN = {
    "carretilla": "Handcart",
    "elevador": "Elevator", "montacargas": "Elevator",
    "rampa mecanica": "Loading Ramp", "gato hidraulico": "Loading Ramp",
    "rampa fija": "Fixed Loading Ramp",
    "a mano": "Manual workforce", "al hombro": "Manual workforce",
    "caminata": "Manual workforce", "caminando": "Manual workforce",
    "descargue a mano": "Manual workforce", "personal externo": "Manual workforce",
    "ninguno": None, "no": None, "na": None, "no aplica": None, "no hay bodega": None
}
GROUP_EN = {
    "madres cabeza de familia": "single_mothers",
    "migrantes": "migrants",
    "victimas del conflicto armado": "conflict_victims",
    "mujeres transgenero": "trans_women",
    "mujeres pertenecientes a grupos etnicos": "ethnic_minority_women",
    "mujeres con movilidad reducida": "women_with_disability",
    "todas las anteriores": "all_of_the_above",
    "ninguna de las anteriores": "none_of_the_above",
}

MAPS = {
    "supply_day": DAY_EN,
    "delivery_modes": DMODE_EN,
    "online_delivery_modes": DMODE_EN,
    "unloading_method": UNLOAD_EN,
    "loading_equipment": EQUIP_EN,
    "female_population_groups": GROUP_EN,
    # add other multi‐label maps here if needed
}
#this are remplaced by multi_col_text
# MULTI_LABEL_COLS = [
#     "supply_day",
#     "delivery_modes",
#     "online_delivery_modes",
#     "unloading_method",
#     "loading_equipment",
#     "female_population_groups",
#     # "top_3_activities" etc.
# ]

# %%
df_translated = df_clean.copy()

# helper to translate a multi-label column
def translate_multi(col, mapping):
    return (
        col.str.lower()
           .str.split(r'\s*,\s*')
           .apply(lambda items: [mapping.get(item.strip(), item.strip())
                                  for item in items
                                  if mapping.get(item.strip(), item.strip())])
           .apply(lambda lst: ', '.join(lst) if lst else '')
    )

for col, mp in MAPS.items():
    df_translated[col] = translate_multi(df_translated[col].astype(str), mp)

# Optionally rename remaining categories, e.g.
df_translated['supply_frequency_per_week'] = (
    df_translated['supply_frequency_per_week']
      .astype(str)
      .replace({
          '1 vez por semana': '1/week',
          '2': '2/week',
          '5': '5/week',
          '6 o más': '6+/week',
          'La periodicidad es quincenal': 'biweekly',
          'La periodicidad es mensual': 'monthly'
      })
)

# %%
df_translated
# Out:
#       id               timestamp                                     email  \
# 0      1 2022-05-17 11:20:36.160      Gestiohumana@111tiendasdebelleza.com
# 1      2 2022-05-18 11:17:48.282   CalzadobucaramangaMedellín2@hotmail.com
# 2      3 2022-05-18 08:28:01.487                                 No aplica
# 3      4 2022-05-16 16:22:43.406  comercializadoracentermedmatur@gmail.com
# 4      5 2022-05-16 15:54:14.360                       pipemotos@gmail.com
# ..   ...                     ...                                       ...
# 482  483 2022-08-01 10:59:07.027                                 No aplica
# 483  484 2022-07-28 14:07:11.238                                 no aplica
# 484  485 2022-08-10 13:32:20.038                                 No aplica
# 485  486 2022-07-28 14:10:37.967                Alejandrohoyos87@gmail.com
# 486  487 2022-07-29 10:03:18.602                  Corporativo@creafam.coop
#
#                                  company_name                est_address  \
# 0           Iversiones111t tiendas de belleza  CL 48 54 43 local 102 108
# 1        Distri zapatos - calzado bucaramanga                 Cr 54 4803
# 2                             Molina y arango            Calle 44a 54 32
# 3                     Comercializadora center             Calle 46 53 05
# 4                                  Pipe motos          Calle  45 53 A 12
# ..                                        ...                        ...
# 482                              Grupo krombi  Cc comercial Japón piso 4
# 483  Comercializadora y distribuidora H&R SAS      Kr 55 46 64 local 119
# 484                                     Kalon       Megacentro local 420
# 485                    Aleko comercializadora      Kr 55 46 65 local 131
# 486                                   Creafam                Kr 55 48 12
#
#            contact_phone  employees has_female_employees  female_employees  \
# 0                5110950         13                   Sí               5.0
# 1             3147907153         12                   Sí               9.0
# 2             3103978026          3                   No               NaN
# 3                5134081         32                   Sí              20.0
# 4    5898256 -3295338608          3                   No               NaN
# ..                   ...        ...                  ...               ...
# 482           3148879396         16                   Sí               8.0
# 483           3186442694          2                   Sí               1.0
# 484            No aplica          3                   Sí               3.0
# 485           3005544704         11                   Sí               4.0
# 486              2315009         20                   Sí              15.0
#
#      female_percentage  ...  safety_perception_bicycle  \
# 0             0.384615  ...                          1
# 1             0.750000  ...                          3
# 2             0.000000  ...                          1
# 3             0.625000  ...                          1
# 4             0.000000  ...                          1
# ..                 ...  ...                        ...
# 482           0.500000  ...                          1
# 483           0.500000  ...                          1
# 484           1.000000  ...                          1
# 485           0.363636  ...                          1
# 486           0.750000  ...                          5
#
#                             loading_equipment  \
# 0                                    Handcart
# 1                                    Handcart
# 2
# 3    Handcart, Elevator, escaleras eléctricas
# 4                                       bahía
# ..                                        ...
# 482                                   ninguna
# 483
# 484                                   ninguni
# 485                                  Handcart
# 486                                  Handcart
#
#                                        delivery_modes  daily_delivery_count  \
# 0                                          Motorcycle                     8
# 1                                    no_home_delivery                     0
# 2                                    no_home_delivery                     0
# 3                                    no_home_delivery                     1
# 4                                    no_home_delivery                     4
# ..                                                ...                   ...
# 482                                     Truck, furgón                    13
# 483  caminata, Motorcycle, vehículo particular, Truck                     1
# 484                                  no_home_delivery                     0
# 485                                        Motorcycle                    10
# 486                                  no_home_delivery                     0
#
#                                 online_delivery_modes  \
# 0                                          Motorcycle
# 1                                        no_ecommerce
# 2                                 vehículo particular
# 3                                        no_ecommerce
# 4                                        no_ecommerce
# ..                                                ...
# 482                                            furgón
# 483  caminata, Motorcycle, vehículo particular, Truck
# 484                                      no_ecommerce
# 485                                        Motorcycle
# 486                                      no_ecommerce
#
#     daily_online_delivery_count supply_frequency_num         econ_main  \
# 0                             8                  NaN  Venta al detalle
# 1                             0                    6  Venta al detalle
# 2                             5                    6  Venta al detalle
# 3                             0                  NaN        Fabricante
# 4                             1                    1         Proveedor
# ..                          ...                  ...               ...
# 482                          13                  NaN         Proveedor
# 483                           1                  NaN  Venta al detalle
# 484                           0                  NaN  Venta al detalle
# 485                           4                  NaN         Proveedor
# 486                           0                    1         Proveedor
#
#                             econ_sub1 econ_sub2
# 0                                 NaN       NaN
# 1                                 NaN       NaN
# 2                                 NaN       NaN
# 3    Compran terminado y comercializa       NaN
# 4                                 NaN       NaN
# ..                                ...       ...
# 482                               NaN       NaN
# 483                               NaN       NaN
# 484                               NaN       NaN
# 485                               NaN       NaN
# 486                               NaN       NaN
#
# [487 rows x 42 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer

df_ml = df_translated.copy()

# prepare a dict of multi-label columns
multi_cols = ['supply_day','loading_schedule','unloading_method',
              'loading_equipment','delivery_modes','online_delivery_modes']
mlb = MultiLabelBinarizer()

for col in multi_cols:
    lists = df_ml[col].str.split(r'\s*,\s*')
    dummies = pd.DataFrame(mlb.fit_transform(lists),
                           columns=[f"{col}_{c}" for c in mlb.classes_],
                           index=df_ml.index)
    df_ml = pd.concat([df_ml, dummies], axis=1).drop(columns=[col])

# now one-hot encode the remaining single‐label categoricals
cat_cols = ['economic_activity','main_products','has_warehouse_space',
            'warehouse_floor','warehouse_within_zuap','warehouse_municipality',
            'warehouse_type','supply_frequency_per_week',
            'safety_perception_motorized','safety_perception_bicycle']
df_dummies = pd.get_dummies(df_ml[cat_cols], drop_first=False)
# finally, combine with numeric
num_cols = ['warehouse_count','warehouse_area_m2','warehouse_height_m',
            'daily_delivery_count','daily_online_delivery_count','employees']
df_with_dummies = pd.concat([df_ml[num_cols], df_dummies], axis=1)

# %%
df_with_dummies
# Out:
#      warehouse_count  warehouse_area_m2  warehouse_height_m  \
# 0                1.0               50.0                 3.0
# 1               40.0              150.0                 1.5
# 2                1.0              130.0                 4.0
# 3                1.0              200.0                 3.0
# 4                1.0               50.0                 3.0
# ..               ...                ...                 ...
# 482              5.0              200.0                 5.0
# 483              1.0               10.0                 2.0
# 484              NaN                NaN                 NaN
# 485              1.0              360.0                 6.0
# 486              NaN                NaN                 NaN
#
#      daily_delivery_count  daily_online_delivery_count  employees  \
# 0                       8                            8         13
# 1                       0                            0         12
# 2                       0                            5          3
# 3                       1                            0         32
# 4                       4                            1          3
# ..                    ...                          ...        ...
# 482                    13                           13         16
# 483                     1                            1          2
# 484                     0                            0          3
# 485                    10                            4         11
# 486                     0                            0         20
#
#      economic_activity_Fabricante  economic_activity_Fabricante Carpintería  \
# 0                           False                                     False
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# 4                           False                                     False
# ..                            ...                                       ...
# 482                         False                                     False
# 483                         False                                     False
# 484                         False                                     False
# 485                         False                                     False
# 486                         False                                     False
#
#      economic_activity_Fabricante Carpintería Marquetería  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 482                                              False
# 483                                              False
# 484                                              False
# 485                                              False
# 486                                              False
#
#      economic_activity_Fabricante Centro de impresiones  ...  \
# 0                                                False   ...
# 1                                                False   ...
# 2                                                False   ...
# 3                                                False   ...
# 4                                                False   ...
# ..                                                 ...   ...
# 482                                              False   ...
# 483                                              False   ...
# 484                                              False   ...
# 485                                              False   ...
# 486                                              False   ...
#
#      safety_perception_motorized_1  safety_perception_motorized_2  \
# 0                            False                           True
# 1                            False                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                          False
# ..                             ...                            ...
# 482                          False                          False
# 483                          False                          False
# 484                          False                          False
# 485                          False                          False
# 486                          False                          False
#
#      safety_perception_motorized_3  safety_perception_motorized_4  \
# 0                            False                          False
# 1                             True                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                           True
# ..                             ...                            ...
# 482                          False                          False
# 483                           True                          False
# 484                          False                          False
# 485                          False                          False
# 486                          False                          False
#
#      safety_perception_motorized_5  safety_perception_bicycle_1  \
# 0                            False                         True
# 1                            False                        False
# 2                             True                         True
# 3                             True                         True
# 4                            False                         True
# ..                             ...                          ...
# 482                           True                         True
# 483                          False                         True
# 484                           True                         True
# 485                           True                         True
# 486                           True                        False
#
#      safety_perception_bicycle_2  safety_perception_bicycle_3  \
# 0                          False                        False
# 1                          False                         True
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 482                        False                        False
# 483                        False                        False
# 484                        False                        False
# 485                        False                        False
# 486                        False                        False
#
#      safety_perception_bicycle_4  safety_perception_bicycle_5
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 482                        False                        False
# 483                        False                        False
# 484                        False                        False
# 485                        False                        False
# 486                        False                         True
#
# [487 rows x 179 columns]

# %%
df_translated.to_csv(r"C:\Users\cgranadamunoz\OneDrive - Universidad Nacional de Colombia\UCC - General\CBD_MDE_2025\data\intermediate\translated_survey.csv", index=False)
df_with_dummies.to_csv(r"C:\Users\cgranadamunoz\OneDrive - Universidad Nacional de Colombia\UCC - General\CBD_MDE_2025\data\intermediate\survey_for_famd.csv", index=False)
